# %%
basedir = '/home/abhinavgupta0110/generalized_nCM'

import os

is_google_colab = False
is_use_GPU = False

# %% [markdown]
# ### Mount the Google drive if needed

# %%
if is_use_GPU:
    gpu_info = !nvidia-smi
    gpu_info = '\n'.join(gpu_info)
    if gpu_info.find('failed') >= 0:
        print('No GPU found!')
    else:
        print(gpu_info)

if is_google_colab:
    from google.colab import drive
    drive.mount('/content/drive')

    # %pip install quadpy
    
os.chdir(os.path.join(basedir, 'generalized_nCMs'))

# %load_ext autoreload

# %% [markdown]
# ### Load modules

# %%
# %autoreload 2

from src.utilities.DDE_Solver import ddeinttf 
from src.utilities.helper_classes import * 
import src.solvers.neuralODE_train_HOTs as ncm
import src.bio_eqn_case.bio_eqn as bio
from src.bio_eqn_case.bio_Eqn_Helper_Classes import * 

import time
import sys
from IPython.core.debugger import set_trace

import numpy as np
import scipy.interpolate
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib import cm
from shutil import move
import pickle

print(tf.__version__) 

tf.keras.backend.set_floatx('float32')
import logging
tf.get_logger().setLevel(logging.ERROR)
# Out:
# 2.5.0

# %% [markdown]
# ## Define some useful classes

# %% [markdown]
# ### Class for user-defined arguments

# %%
class bio_eq_ncm_args(ncm.ncm_arguments, bio.bio_eqn_args):

    def __init__(self, batch_time = 12, batch_time_skip = 2, batch_size = 5, epochs = 500, learning_rate = 0.05, 
                 decay_rate = 0.95, test_freq = 1, plot_freq = 2, 
                 tau_max = 1.1, tau = 0.2,
                 model_dir = 'ROM_nDistDDE_testcase/model_dir_test', restart = 0, val_percentage = 0.2,
                 T = 365, nt = 365, nz = 50, z_max = -100, a = 0.07, g_max = 0.81e-5 * (60*60*24), k_P = 0.06, 
                 k_D = 0.01, k_W = 0.08, K_N = 0.5, K_P = 0.25, m_p = 9.26e-7 * (60*60*24), m_z = 6.94e-7 * (60*60*24), 
                 T_opt = 20, mu_max = 3.25e-5 * (60*60*24), alpha = 1.62e-6 * (60*60*24), beta = 3.24e-8 * (60*60*24), 
                 epsilon = 1.736e-7 * (60*60*24), lamb = 0.3, gamma = 0.4, C_P = 6.625, C_Z = 5.625, C_D = 7.5, 
                 gamma_c = 0.01, T_bio_min = 10, T_bio_max = 10, Temp = None, Salt = None, I_0 = 158.075, K_z0 = 8.64, 
                 K_zb = 0.0864, gamma_K = 0.1, bio_model_low_complex = 'NPZD-OA', 
                 bio_model_high_complex = 'NPZD-OA', isplot = True,
                 ode_alg_name = 'dopri5', nsteps = -1, is_tstart_zero = True, 
                 lambda_l1_mark = 0., lambda_l2_mark = 0., 
                 lambda_l1_non_mark = 0., lambda_l2_non_mark = 0., prune_thres = 0., mse_weight = 0., max_deriv = 2,
                 acc = 2, extra_terms_high_complex = 1, extra_terms_low_complex = 0, 
                 train_ens_size = 1, ens_to_plot = -1, skip_bnd = 0): # add more arguments as needed

        ncm.ncm_arguments.__init__(self, data_size = nt, batch_time = batch_time, batch_time_skip = batch_time_skip, batch_size = batch_size, epochs = epochs,
                           learning_rate = learning_rate, decay_rate = decay_rate, test_freq = test_freq, plot_freq = plot_freq, 
                           tau_max = tau_max, tau = tau, model_dir = model_dir, restart = restart, val_percentage = val_percentage, 
                           isplot = isplot, is_tstart_zero = is_tstart_zero)

        self.args_train_lf = [bio.bio_eqn_args(T = T, nt = nt, nz = nz, z_max = z_max, a = a, g_max = g_max, k_P = k_P, 
                                  k_D = k_D, k_W = k_W, K_N = K_N, K_P = K_P, m_p = m_p, m_z = m_z, T_opt = T_opt, 
                                  mu_max = mu_max, alpha = alpha, beta = beta, epsilon = epsilon, lamb = lamb, 
                                  gamma = gamma, C_P = C_P, C_Z = C_Z, C_D = C_D, gamma_c = gamma_c, T_bio_min = T_bio_min, 
                                  T_bio_max = T_bio_max, bio_model = bio_model_low_complex, Temp = Temp, Salt = Salt, I_0 = I_0, 
                                  K_z0 = K_z0, K_zb = K_zb, gamma_K = gamma_K, extra_terms = extra_terms_low_complex,
                                  acc = acc, max_deriv = max_deriv, skip_bnd = skip_bnd)]
        
        self.args_train_hf = [bio.bio_eqn_args(T = T, nt = nt, nz = nz, z_max = z_max, a = a, g_max = g_max, k_P = k_P, 
                                  k_D = k_D, k_W = k_W, K_N = K_N, K_P = K_P, m_p = m_p, m_z = m_z, T_opt = T_opt, 
                                  mu_max = mu_max, alpha = alpha, beta = beta, epsilon = epsilon, lamb = lamb, 
                                  gamma = gamma, C_P = C_P, C_Z = C_Z, C_D = C_D, gamma_c = gamma_c, T_bio_min = T_bio_min, 
                                  T_bio_max = T_bio_max, bio_model = bio_model_high_complex, Temp = Temp, Salt = Salt, I_0 = I_0, 
                                  K_z0 = K_z0, K_zb = K_zb, gamma_K = gamma_K, extra_terms = extra_terms_high_complex,
                                  acc = acc, max_deriv = max_deriv, skip_bnd = skip_bnd)]
        
        self.train_ens_size = train_ens_size
        
        self.args_eval_hf = self.args_train_hf[ens_to_plot]
        self.args_eval_lf = self.args_train_lf[ens_to_plot]
        
        self.bio_model_low_complex = bio_model_low_complex
        self.bio_model_high_complex = bio_model_high_complex
        self.ode_alg_name = ode_alg_name
        self.nsteps = nsteps
        
        self.lambda_l1_mark = lambda_l1_mark
        self.lambda_l2_mark = lambda_l2_mark
        self.lambda_l1_non_mark = lambda_l1_non_mark
        self.lambda_l2_non_mark = lambda_l2_non_mark
        self.prune_thres = prune_thres
        self.mse_weight = mse_weight

# %%
class sigmoid_func:
    def __init__(self, T_top, T_bot, z_max):
        self.T_top = T_top
        self.T_bot = T_bot
        self.z_max = z_max
        
    def __call__(self, z, t):
        A = self.T_top
        K = self.T_bot
        C = 1
        Q = 0.5
        B = 0.25
        nu = 2.0
        T = lambda x: A + ((K - A) / (C + Q * np.exp(-B*x))**(1./nu))
        
        T = np.stack([ T(np.abs(z) + self.z_max/2) for i in range(t.shape[0])], axis=0)
        
        return T

# %% [markdown]
# ### Define the neural net architecture

# %%
class OA_constraint(tf.keras.constraints.Constraint):
    
    def __init__(self, app):
        self.app = app

    def __call__(self, w):
        
        w = tf.concat([-(w[:, 1:2] + w[:, 2:3] + w[:, 3:4]), w[:, 1:2], w[:, 2:3], w[:, 3:4]], axis=-1)
        
        w = tf.concat([w, - self.app.C_P * w[:, 1:2] - self.app.C_Z * w[:, 2:3] - self.app.C_D * w[:, 3:4], -w[:, 0:1] / self.app.water_density], axis=-1)
        
        return w

# %%
class TruncatedNormal_with_OA_constraint(tf.keras.initializers.Initializer):

    def __init__(self, stddev, weight_constraint):

        self.stddev = stddev
        self.weight_constraint = weight_constraint

    def __call__(self, shape, dtype=None, **kwargs):
        
        w = tf.random.truncated_normal(shape, stddev=self.stddev)
        
        return self.weight_constraint(w)

# %%
class NNFunc_mark(tf.keras.Model):

    def __init__(self, weight_constraint, **kwargs):
        super(NNFunc_mark, self).__init__(**kwargs)
        
        self.out = tf.keras.layers.Dense(6, activation='linear',
                                       kernel_initializer=TruncatedNormal_with_OA_constraint(stddev=0.00001, weight_constraint = weight_constraint), use_bias=False,
                                        kernel_constraint = weight_constraint)
        
    def process_input(self, y, shp):     
               
        y = tf.reshape(y, shp)
        
        return y
    
    @tf.function
    def pass_layers(self, z):
        
        for i in range(len(self.layers)):
            z = self.layers[i](z)
            
        return z
    
    def call(self, z):
        
        z = z[:, :, 0]
        
        z_shp = tf.shape(z)
        z = tf.transpose(tf.reshape(z, [z_shp[0], 6, -1]), perm = [0, 2, 1])
        
        z_shp = tf.shape(z)
        
        z = self.process_input(z, [-1, 6])
        
        z = tf.cast(z, tf.float64)
        
        z_itself = tf.einsum('ab, ab -> ab', z, z)
        
        z_lim = tf.einsum('ab, ab -> ab', z_itself, 1. / (1. + z))
        
        z = tf.cast(tf.concat([z[:, 2:3], z_itself[:, 2:3], z_lim[:, 2:3], tf.math.exp(z)[:, 2:3]], axis=-1), tf.float32)
        
        z = self.pass_layers(tf.cast(z, tf.float32))
        
        z = self.process_input(z, z_shp)
        
        z = tf.reshape(tf.transpose(z, perm = [0, 2, 1]), [z_shp[0], -1])
        return z

# %%
class ODEFunc(tf.keras.Model):

    def __init__(self, mark_nn_part, rom_model, app, norm_const, **kwargs):
        super(ODEFunc, self).__init__(**kwargs)
        self.mark_nn_part = mark_nn_part
        self.rom_model = rom_model
        self.args = app
        
        self.norm_const = norm_const
        
    def overwrite_rom(self, app, rom_model, norm_const):
        self.rom_model = rom_model
        self.args = app
        self.norm_const = norm_const
    
    def process_input(self, zy, t ,tau, flag_fwd=0):     
        
        input = [self.compute_derivatives(zy(t)[:, :self.args.state_dim], flag_fwd)]
        
        return input
    
    def call_nn_part_indiv(self, z, flag_fwd = 0):
        
        z = self.compute_derivatives(z, flag_fwd)
        
        return self.mark_nn_part(z)
    
    def compute_derivatives(self, u, flag_fwd = 0):
        
        u_stack = [u]
        
        for i in range(1, self.args.max_deriv+1):
            u_stack.append(np.einsum('ab, cb -> ca', self.rom_model.full_vander[i], u.numpy()))
        
        u_stack = tf.convert_to_tensor(np.stack(u_stack, axis=-1))
        
        return u_stack

    def __call__(self, uy, t ,tau, t_start = np.array([0.])):    
        
        input = self.process_input(uy, t ,tau)
        
        u_t = input[0][:, :, 0]
        
        du_dt = self.rom_model(uy, t, t_start)
        
        du_dt = du_dt + self.call_nn_part_indiv(u_t).numpy()
        
        if self.args.skip_bnd != 1:
            du_dt = self.rom_model.apply_bnd(t+t_start, u_t, du_dt)
        
        du_dt = tf.convert_to_tensor(du_dt, dtype=tf.float32)
        
        return du_dt

# %% [markdown]
# ### Initialize model related parameters

# %%
args = bio_eq_ncm_args(batch_time = 3, batch_time_skip = 2, batch_size = 4, epochs = 200, learning_rate = 0.075, 
                 decay_rate = 0.97, test_freq = 25, plot_freq = 25, 
                 model_dir = 'BioOA_nODE_testcase/model_dir_case3fb', restart = 0, val_percentage = 1.,
                 T = 30, nt = 300, nz = 20, z_max = -100, a = 0.07, g_max = 0.81e-5 * (60*60*24), k_P = 0.06, 
                 k_D = 0.01, k_W = 0.08, K_N = 0.5, K_P = 0.25, m_p = 9.26e-7 * (60*60*24), m_z = 6.94e-7 * (60*60*24) / 2, 
                 T_opt = 20, mu_max = 3.25e-5 * (60*60*24), alpha = 1.62e-6 * (60*60*24), beta = 3.24e-8 * (60*60*24), 
                 epsilon = 1.736e-7 * (60*60*24), lamb = 0.3, gamma = 0.4, C_P = 6.625, C_Z = 5.625, C_D = 7.5, 
                 gamma_c = 0.01, T_bio_min = 10, T_bio_max = 20, Temp = sigmoid_func(20, 20, -100), 
                 Salt = sigmoid_func(31.4, 32.8, -100), I_0 = 158.075, K_z0 = 8.64, 
                 K_zb = 0.0864, gamma_K = 0.1, bio_model_low_complex = 'NPZD-OA', 
                 bio_model_high_complex = 'NPZD-OA', isplot = True, ode_alg_name = 'dopri5', nsteps = 100, 
                 is_tstart_zero = False, lambda_l1_mark = 3 * 5e-4, lambda_l2_mark = 1e-3, 
                 prune_thres = 5e-3, mse_weight = 0., max_deriv = 2,
                 acc = 2, extra_terms_high_complex = 1, skip_bnd = 0)

# %% [markdown]
# ### Make a copy of the current script

# %%
testcase_dir = 'generalized_nCMs/testcases/bio_eqn'
save_dir_obj = save_dir(args = args, basedir = basedir, testcase_dir = testcase_dir, save_user_inputs=False)
save_dir_obj(script_name = 'neuralODE_BioOA_Eqn_1D_TestCase')

# %% [markdown]
# ### Run setup

# %%
os.chdir(os.path.join(basedir, testcase_dir))

# %run -i setup
# Out:
# Higher complexity model done!

# %%
### Define a custom loss function
class custom_loss():
    
    def __init__(self, args, x, mse_weight = 0.):
        self.args = args
        self.base_str = 'cdefghijklmnopqrstuvwxyz' # A helper string
        self.area = self.integral(tf.ones(x.shape), x, axis = 0)
        self.x = x
        self.mse_weight = mse_weight
        
    def overwrite(self, args, x):
        self.args = args
        self.x = x
        self.area = self.integral(tf.ones(x.shape), x, axis = 0)
        
    def integral(self, y, x, axis = -1):
        dx = x[1:] - x[0:-1]
        
        y_avg = 0.5 * (tf.gather(y, list(range(0, y.shape[axis]-1)), axis=axis) + tf.gather(y, list(range(1, y.shape[axis])), axis=axis))
        
        var_shape_len = len(tf.shape(y_avg).numpy())
        shape_str = self.base_str[:var_shape_len]

        y_int = tf.einsum(shape_str + ',' + shape_str[axis] + \
                               '->' + shape_str, tf.cast(y_avg, tf.float64), \
                                                        tf.cast(dx, tf.float64))
        
        return tf.cast(tf.reduce_sum(y_int, axis=axis), tf.float32)

    def __call__(self, true_y, pred_y):      
        loss = tf.abs(pred_y - true_y) 
        loss_shp = loss.shape
        loss = tf.transpose(tf.reshape(loss, loss_shp[0:2] + [int(self.args.state_dim / self.args.nz), self.args.nz]), perm = [0, 1, 3, 2])
        scale = tf.tile(tf.convert_to_tensor([[[[1., 4., 1., 1., 1./2., 10.]]]]), loss.shape[0:-1] + [1])
        loss = tf.cast(tf.einsum('abcd, abcd -> abcd', tf.cast(loss, tf.float64), tf.cast(scale, tf.float64)), tf.float32)
        loss = tf.reduce_sum(loss, axis=-1)
        loss = tf.reduce_sum(loss, -1) / self.area #Just a hack to get pointwise derivatives
        loss = tf.reduce_mean(loss, axis=0)
        
        return loss
    
    def eval_mode(self, true_y, pred_y):
        loss = tf.abs(pred_y - true_y) 
        loss_shp = loss.shape
        loss = tf.transpose(tf.reshape(loss, loss_shp[0:2] + [int(self.args.state_dim / self.args.nz), self.args.nz]), perm = [0, 1, 3, 2])
        loss = tf.reduce_sum(loss, axis=-1)
        loss = self.integral(loss, self.x) / self.area
        loss = tf.reduce_mean(loss, axis=0)
        
        return loss
    
    def reglularizer(self, model, lambda_l1, lambda_l2):
        weights   = model.trainable_weights
        
        lossL2 = tf.add_n([ tf.nn.l2_loss(v) for v in weights ]) 
        
        lossL1 = tf.add_n([ tf.reduce_sum(tf.abs(tf.reshape(v, [-1]))) for v in weights ]) 
        
        loss = lambda_l1 * lossL1 + lambda_l2 * lossL2
        
        return loss

# %% [markdown]
# ## Main part starts here

# %% [markdown]
# ### Make objects and define learning-rate schedule

# %%
time_meter = ncm.RunningAverageMeter(0.97)

grid_obj = fdgen.grid(args.args_eval_lf, args.args_eval_lf.z)
deriv_obj = fdgen.deriv(args.args_eval_lf, grid_obj)

eval_rom_rhs_obj = bio.bio_eqn(args.args_eval_lf, K_z_obj, grid_obj, deriv_obj)
func = ODEFunc(NNFunc_mark(OA_constraint(args.args_eval_lf)), eval_rom_rhs_obj, args.args_eval_lf, None)

loss_obj = custom_loss(args.args_eval_lf, tf.convert_to_tensor(grid_obj.x_grid_real), args.mse_weight)

plot_obj = custom_plot(tf.concat([true_x_low_complex, val_true_x_low_complex], axis=0), tf.concat([x_low_complex, val_x_low_complex], axis=0), 
                       args.args_eval_lf.z, tf.concat([t, val_t], axis=0), save_dir_obj.figsave_dir, args.args_eval_lf, args.restart)
loss_history = ncm.history(args)

initial_learning_rate = args.learning_rate
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=args.niters,
    decay_rate=args.decay_rate,
    staircase=True)

# %% [markdown]
# ### Quick test to see how the true coefficients looks like

# %%
if args.restart == 1: 
    func.load_weights(tf.train.latest_checkpoint(save_dir_obj.checkpoint_dir))
    pred_y = ddeinttf(func, true_x0_low_complex, tf.concat([t, val_t], axis=0), fargs=(args.tau,), alg_name = args.ode_alg_name, nsteps = args.nsteps)
    
    plot_obj.plot(pred_y, epoch = 0)

    loss_history.read()
    
    initial_learning_rate = 0.01
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate, decay_steps=args.niters, decay_rate=0.97, staircase=True)
    
else:
    plot_obj.plot(epoch = -1)

# %% [markdown]
# ### Training starts here

# %%
optimizer = tf.keras.optimizers.RMSprop(learning_rate = lr_schedule)

nODE_train_obj = ncm.train_nODE(func = func, rom_ens = [train_rom_rhs_obj], loss_obj = loss_obj,
                            optimizer = optimizer, args = args, plot_obj = plot_obj, time_meter = time_meter, checkpoint_dir = save_dir_obj.checkpoint_prefix,
                            validation_obj = val_obj, loss_history_obj = loss_history)

nODE_train_obj.train(true_z_ens = [true_x_low_complex], true_z0_ens = [true_x0_low_complex], 
                         t = t, eval_true_z = true_x_low_complex, eval_true_z0 = true_x0_low_complex, 
                         eval_val_true_z = val_true_x_low_complex, eval_rom = eval_rom_rhs_obj, 
                         norm_eval = None, norm_train_ens = [None])
# Out:
# Epoch 0000 | Train Loss 1.528945 | Val Loss 4.251164 | Time Elapsed 0.0000 mins
# Iterations:  83%|████████▎ | 5/6 [05:56<01:11, 71.90s/it]
# /home/abhinavgupta0110/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ode.py:1181: UserWarning: dopri5: larger nsteps is needed
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /home/abhinavgupta0110/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ode.py:1181: UserWarning: dopri5: step size becomes too small
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /home/abhinavgupta0110/anaconda3/lib/python3.8/site-packages/scipy/interpolate/interpolate.py:626: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# /home/abhinavgupta0110/anaconda3/lib/python3.8/site-packages/scipy/interpolate/interpolate.py:626: RuntimeWarning: invalid value encountered in add
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# Iterations: 100%|██████████| 6/6 [08:23<00:00, 83.99s/it]
# Iterations: 100%|██████████| 6/6 [11:50<00:00, 118.36s/it]
# Iterations: 100%|██████████| 6/6 [12:05<00:00, 120.91s/it]
# Iterations: 100%|██████████| 6/6 [11:59<00:00, 119.86s/it]
# Iterations: 100%|██████████| 6/6 [11:39<00:00, 116.64s/it]
# Iterations: 100%|██████████| 6/6 [11:44<00:00, 117.48s/it]
# Iterations: 100%|██████████| 6/6 [11:58<00:00, 119.74s/it]
# Iterations: 100%|██████████| 6/6 [12:08<00:00, 121.39s/it]
# Iterations: 100%|██████████| 6/6 [12:05<00:00, 120.86s/it]
# Iterations: 100%|██████████| 6/6 [11:51<00:00, 118.67s/it]
# Iterations: 100%|██████████| 6/6 [11:45<00:00, 117.66s/it]
# Iterations: 100%|██████████| 6/6 [12:01<00:00, 120.21s/it]
# Iterations: 100%|██████████| 6/6 [12:17<00:00, 122.96s/it]
# Iterations: 100%|██████████| 6/6 [12:14<00:00, 122.38s/it]
# Iterations: 100%|██████████| 6/6 [15:28<00:00, 154.74s/it]
# Iterations: 100%|██████████| 6/6 [16:21<00:00, 163.59s/it]
# Iterations: 100%|██████████| 6/6 [15:31<00:00, 155.22s/it]
# Iterations: 100%|██████████| 6/6 [15:40<00:00, 156.73s/it]
# Iterations: 100%|██████████| 6/6 [16:02<00:00, 160.38s/it]
# Iterations: 100%|██████████| 6/6 [15:46<00:00, 157.81s/it]
# Iterations: 100%|██████████| 6/6 [15:12<00:00, 152.08s/it]
# Iterations: 100%|██████████| 6/6 [13:26<00:00, 134.45s/it]
# Iterations: 100%|██████████| 6/6 [12:39<00:00, 126.67s/it]
# Iterations: 100%|██████████| 6/6 [14:35<00:00, 145.92s/it]
# Iterations: 100%|██████████| 6/6 [12:38<00:00, 126.40s/it]
# Epoch 0025 | Train Loss 6.763085 | Val Loss 8.404971 | LR 0.0350 | Time Elapsed 11.5095 mins
# <tf.Variable 'dense/kernel:0' shape=(4, 6) dtype=float32, numpy=
# array([[ 1.1541902e+01, -3.5295601e+00, -4.4471878e-01, -7.5676227e+00,
#          8.2642052e+01, -1.1226111e-02],
#        [ 7.3794508e+00, -2.5097363e+00,  2.7496958e+00, -7.6194105e+00,
#          5.8305542e+01, -7.1775462e-03],
#        [ 8.1863251e+00, -2.4011121e+00,  1.5971056e+00, -7.3823185e+00,
#          6.2291039e+01, -7.9623442e-03],
#        [           nan, -5.3111868e+00,            nan, -7.6930408e+00,
# Iterations: 100%|██████████| 6/6 [11:09<00:00, 111.63s/it]
# Iterations: 100%|██████████| 6/6 [11:28<00:00, 114.72s/it]
# Iterations: 100%|██████████| 6/6 [11:17<00:00, 112.85s/it]
# Iterations: 100%|██████████| 6/6 [11:10<00:00, 111.81s/it]
# Iterations: 100%|██████████| 6/6 [11:21<00:00, 113.53s/it]
# Iterations: 100%|██████████| 6/6 [11:14<00:00, 112.46s/it]
# Iterations: 100%|██████████| 6/6 [11:25<00:00, 114.19s/it]
# Iterations: 100%|██████████| 6/6 [11:17<00:00, 112.91s/it]
# Epoch 0100 | Train Loss 6.763085 | Val Loss 8.404971 | LR 0.0036 | Time Elapsed 11.6235 mins
# <tf.Variable 'dense/kernel:0' shape=(4, 6) dtype=float32, numpy=
# array([[ 2.1110569e+01, -6.4997945e+00, -1.2369068e+00, -1.3373869e+01,
#          1.5032275e+02, -2.0532977e-02],
#        [ 1.4103838e+01, -4.7286849e+00,  4.0834794e+00, -1.3458632e+01,
#          1.0929771e+02, -1.3717952e-02],
#        [ 1.5266594e+01, -4.4631290e+00,  1.9376131e+00, -1.2741078e+01,
#          1.1422725e+02, -1.4848894e-02],
#        [           nan, -9.5805025e+00,            nan, -1.3627118e+01,
#                    nan,            nan]], dtype=float32)>
# Iterations: 100%|██████████| 6/6 [11:26<00:00, 114.47s/it]
# Iterations: 100%|██████████| 6/6 [11:10<00:00, 111.69s/it]
# Iterations: 100%|██████████| 6/6 [11:10<00:00, 111.75s/it]
# Iterations: 100%|██████████| 6/6 [11:10<00:00, 111.79s/it]
# Iterations: 100%|██████████| 6/6 [11:27<00:00, 114.66s/it]
# Iterations:  83%|████████▎ | 5/6 [10:37<02:07, 127.54s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/generalized_nCM/generalized_nCMs/testcases/bio_eqn/setup.py in <module>
#       5                             validation_obj = val_obj, loss_history_obj = loss_history)
#       6
# ----> 7 nODE_train_obj.train(true_z_ens = [true_x_low_complex], true_z0_ens = [true_x0_low_complex],
#       8                          t = t, eval_true_z = true_x_low_complex, eval_true_z0 = true_x0_low_complex,
#       9                          eval_val_true_z = val_true_x_low_complex, eval_rom = eval_rom_rhs_obj,
#
# ~/generalized_nCM/generalized_nCMs/src/solvers/neuralODE_train_HOTs.py in train(self, true_z_ens, true_z0_ens, t, eval_true_z, eval_true_z0, eval_val_true_z, eval_rom, norm_eval, norm_train_ens)
#     289 #                     print(pred_z)
#     290 #                     print('/n')
# --> 291                     pred_adj_intrvl, batch_adj_t_intrvl, grads_avg_mark_nn_part = self.bkwd_pass(pred_z, pred_z0_z_interp, dloss_dpred_z_whole, batch_t, batch_t_start)
#     292
#     293                     grads_avg_mark_nn_part = [tf.clip_by_norm(g, 1.) for g in grads_avg_mark_nn_part]
#
# ~/generalized_nCM/generalized_nCMs/src/solvers/neuralODE_train_HOTs.py in bkwd_pass(self, pred_zy, pred_z0_z_interp, dloss_dpred_z_whole, batch_t, batch_t_start)
#     221
#     222             # Solve for the augmented adjoint ODE
# --> 223             pred_adj_intrvl = ddeinttf(self.adj_func, adj_eqn_ic_interp, batch_adj_t_intrvl, fargs = (self.args.tau, pred_z0_z_interp, batch_t_start), alg_name = self.args.ode_alg_name, nsteps = self.args.nsteps)
#     224
#     225             # Compute gradients w.r.t. trainable weights of mark_nn_part
#
# ~/generalized_nCM/generalized_nCMs/src/utilities/DDE_Solver.py in ddeinttf(func, g, tt, fargs, alg_name, nsteps)
#     157     else:
#     158         dde_.set_integrator(alg_name, nsteps = nsteps)
# --> 159     results = [dde_.integrate(dde_.t + dt) for dt in np.diff(tt)]
#     160     return tf.concat([tf.expand_dims(g(tt[0]), 0), tf.convert_to_tensor(results, tf.float32)], 0)
#
# ~/generalized_nCM/generalized_nCMs/src/utilities/DDE_Solver.py in <listcomp>(.0)
#     157     else:
#     158         dde_.set_integrator(alg_name, nsteps = nsteps)
# --> 159     results = [dde_.integrate(dde_.t + dt) for dt in np.diff(tt)]
#     160     return tf.concat([tf.expand_dims(g(tt[0]), 0), tf.convert_to_tensor(results, tf.float32)], 0)
#
# ~/generalized_nCM/generalized_nCMs/src/utilities/DDE_Solver.py in integrate(self, t, step, relax)
#      74
#      75     def integrate(self, t, step=0, relax=0):
# ---> 76         scipy.integrate.ode.integrate(self, t, step, relax)
#      77         self.Y.update(self.t, self.y)
#      78         return np.reshape(self.y, self.Y.data_shape)
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ode.py in integrate(self, t, step, relax)
#     431
#     432         try:
# --> 433             self._y, self.t = mth(self.f, self.jac or (lambda: None),
#     434                                   self._y, self.t, t,
#     435                                   self.f_params, self.jac_params)
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ode.py in run(self, f, jac, y0, t0, t1, f_params, jac_params)
#    1174
#    1175     def run(self, f, jac, y0, t0, t1, f_params, jac_params):
# -> 1176         x, y, iwork, istate = self.runner(*((f, t0, y0, t1) +
#    1177                                           tuple(self.call_args) + (f_params,)))
#    1178         self.istate = istate
#
# ~/generalized_nCM/generalized_nCMs/src/utilities/DDE_Solver.py in f2(t, y, args)
#      68         def f2(t, y, args):
#      69             self.Y.update(t, y)
# ---> 70             return tf.reshape(f(self.Y, t, *args), [-1]).numpy()
#      71
#      72         scipy.integrate.ode.__init__(self, f2, jac)
#
# ~/generalized_nCM/generalized_nCMs/src/solvers/neuralODE_train_HOTs.py in __call__(self, lam_mu, t, tau, zy, t_start)
#      63
#      64         if self.jac is not None:
# ---> 65             drom_dz_stack_deriv = tf.convert_to_tensor(self.jac(dz_dx_stack_deriv.numpy(), t, t_start))
#      66
#      67         else:
#
# ~/generalized_nCM/generalized_nCMs/src/bio_eqn_case/bio_eqn.py in jac(self, x_t_stack, t, t_start)
#     258
#     259         f_T = np.exp( - self.app.a * np.abs(self.app.Temp(self.app.z, t) - self.app.T_opt))
# --> 260         I_t = self.PAR(t, self.app.I_0_t)
#     261         f_N = x_t[:, 0*self.app.nz:1*self.app.nz] / (self.app.K_N + x_t[:, 0*self.app.nz:1*self.app.nz])
#     262
#
# ~/generalized_nCM/generalized_nCMs/src/bio_eqn_case/bio_eqn.py in PAR(self, t, I_0_t)
#     114     def PAR(self, t, I_0_t):
#     115
# --> 116         self.I = lambda t: np.stack([I_0_t(t[i]) * np.exp(self.app.k_W * self.app.z.numpy()) for i in range(t.shape[0])], axis=0)
#     117
#     118 #         I_P = np.concatenate([np.expand_dims(np.zeros(P[:, 0].shape), axis=-1), integrate_simp_cumsum(P, self.app.z, axis=-1)], axis=-1)
#
# KeyboardInterrupt:
